# %%
import os
import json
from openai import OpenAI
from dotenv import load_dotenv



load_dotenv("api_key.env")
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

acm_ccs_structure = [
    {
        "high_level_domain": "General and reference",
        "subdomains": [
            {
                "subdomain": "Document types",
                "examples": ["Surveys and overviews", "Reference works", "General conference proceedings", "Biographies", "General literature", "Computing standards, RFCs and guidelines"
                ]
            },
            {
                "subdomain": "Cross-computing tools and techniques",
                "examples": ["Reliability", "Empirical studies", "Measurement", "Metrics","Evaluation", "Experimentation", "Estimation", "Design", "Performance", "Validation", "Verification"
                ]
            }
        ]
    },
    {
        "high_level_domain": "Computer systems organization",
        "subdomains": [
            {"subdomain": "Architectures", "examples": ["Serial architectures", "Parallel architectures", "Distributed architectures", "Other architectures"]},
            {"subdomain": "Embedded and cyber-physical systems", "examples": ["Sensor networks", "Robotics", "Sensors and actuators", "System on a chip", "Embedded systems"]},
            {"subdomain": "Real-time systems", "examples": ["Real-time operating systems", "Real-time languages", "Real-time system specification", "Real-time system architecture"]},
            {"subdomain": "Dependable and fault-tolerant systems and networks", "examples": ["Reliability", "Availability", "Maintainability and maintenance", "Processors and memory architectures", "Secondary storage organization", "Redundancy", "Fault-tolerant network topologies"]}
        ]
    },
    {
        "high_level_domain": "Hardware",
        "subdomains": [
            {"subdomain": "Printed circuit boards", "examples": ["Electromagnetic interference and compatibility", "PCB design and layout"]},
            {"subdomain": "Communication hardware, interfaces and storage", "examples": ["Signal processing systems", "Sensors and actuators", "Buses and high-speed links", "Displays and imagers", "External storage", "Networking hardware", "Printers", "Sensor applications and deployments", "Sensor devices and platforms", "Sound-based input / output", "Tactile and hand-based interfaces", "Scanners", "Wireless devices", "Wireless integrated network sensors", "Electro-mechanical devices" ]},
            {"subdomain": "Very large scale integration design", "examples": ["3D integrated circuits", "Analog and mixed-signal circuits", "Application-specific VLSI designs", "Design reuse and communication-based design", "Design rules", "Economics of chip design and manufacturing", "Full-custom circuits", "VLSI design manufacturing considerations", "On-chip resource management", "On-chip sensors", "Standard cell libraries", "VLSI packaging", "VLSI system specification and constraints"]},
            {"subdomain": "Power and energy", "examples": ["Thermal issues", "Energy generation and storage", "Energy distribution", "Impact on the environment", "Power estimation and optimization"]},
            {"subdomain": "Hardware validation", "examples": ["Functional verification", "Physical verification", "Post-manufacture validation and debug"]},
            {"subdomain": "Hardware test", "examples": ["Analog, mixed-signal and radio frequency test", "Physical verification", "Post-manufacture validation and debug"]},
            {"subdomain": "Electronic design automation", "examples": ["High-level and register-transfer level synthesis", "Hardware description languages and compilation", "Logic synthesis", "Modeling and parameter extraction", "Physical design (EDA)", "Timing analysis", "Methodologies for EDA"]},
            {"subdomain": "Robustness", "examples": ["Fault tolerance", "Design for manufacturability", "Hardware reliability", "Safety critical systems"]},
            {"subdomain": "Emerging technologies", "examples": ["Analysis and design of emerging devices and systems", "Hardware description languages and compilation", "Biology-related information processing", "Circuit substrates", "Electromechanical systems", "Emerging interfaces", "Memory and dense storage", "Emerging optical and photonic technologies", "Reversible logic", "Plasmonics", "Quantum technologies", "Spintronics and magnetic technologies"]}

        ]
    },
    {
        "high_level_domain": "Networks",
        "subdomains": [
            {"subdomain": "Network architectures", "examples": ["Network design principles", "Programming interfaces"]},
            {"subdomain": "Network protocols", "examples": ["Network protocol design", "Protocol correctness", "Link-layer protocols", "Network layer protocols", "Transport protocols", "Session protocols", "Presentation protocols", "Application layer protocols", "OAM protocols", "Cross-layer protocols", "Network File System (NFS) protocol"]},
            {"subdomain": "Network components", "examples": ["Intermediate nodes", "Physical links", "Middle boxes / network appliances", "End nodes", "Wireless access points, base stations and infrastructure", "Logical nodes"]},
            {"subdomain": "Network algorithms", "examples": ["Data path algorithms", "Control path algorithms", "Network economics"]},
            {"subdomain": "Network performance evaluation", "examples": ["Network performance modeling", "Network simulations", "Network experimentation", "Network performance analysis", "Network measurement"]},
            {"subdomain": "Network properties", "examples": ["Network security", "Network range", "Network structure", "Network dynamics", "Network reliability", "Network mobility", "Network manageability", "Network privacy and anonymity"]},
            {"subdomain": "Network services", "examples": ["Naming and addressing", "Cloud computing", "Location based services", "Programmable networks", "In-network processing", "Network management", "Network monitoring"]},
            {"subdomain": "Network types", "examples": ["Network on chip", "Home networks", "Storage area networks", "Data center networks", "Wired access networks", "Cyber-physical networks", "Mobile networks", "Overlay and other logical network structures", "Wireless access networks", "Ad hoc networks", "Public Internet", "Packet-switching networks"]}
        ]
    },
    {
        "high_level_domain": "Software and its engineering",
        "subdomains": [
            {"subdomain": "Software organization and properties", "examples": ["Contextual software domains", "Software system structures", "Software functional properties", "Extra-functional properties"]},
            {"subdomain": "Software notations and tools", "examples": ["General programming languages", "Formal language definitions", "Compilers", "Context specific languages", "System description languages", "Development frameworks and environments", "Software configuration management and version control systems", "Software libraries and repositories", "Software maintenance tools"]},
            {"subdomain": "Software creation and management", "examples": ["Designing software", "Software development process management", "Software development techniques", "Software verification and validation", "Software post-development issues", "Collaboration in software development", "Search-based software engineering"]}
        ]
    },
    {
        "high_level_domain": "Information systems",
        "subdomains": [
            {"subdomain": "Data management systems", "examples": ["Database design and models", "Data structures", "Database management system engines", "Query languages", "Database administration", "Information integration", "Middleware for databases"]},
            {"subdomain": "Information storage systems", "examples": ["Information storage technologies", "Record storage systems", "Storage replication", "Storage architectures", "Storage management"]},
            {"subdomain": "Information systems applications", "examples": ["Enterprise information systems", "Collaborative and social computing systems and tools", "Spatial-temporal systems", "Decision support systems", "Mobile information processing systems", "Process control systems", "Multimedia information systems", "Data mining", "Digital libraries and archives", "Computational advertising", "Computing platforms"]},
            {"subdomain": "World Wide Web", "examples": ["Web searching and information discovery", "Online advertising", "Web mining", "Web applications", "Web interfaces", "Web services", "Web data description languages"]},
            {"subdomain": "Information retrieval", "examples": ["Document representation", "Information retrieval query processing", "Users and interactive retrieval", "Retrieval models and ranking", "Retrieval tasks and goals", "Evaluation of retrieval results", "Search engine architectures and scalability", "Specialized information retrieval"]}
        ]
    },
    {
        "high_level_domain": "Security and privacy",
        "subdomains": [
            {"subdomain": "Cryptography", "examples": ["Key management", "Public key (asymmetric) techniques", "Symmetric cryptography and hash functions", "Cryptanalysis and other attacks", 
            "Information-theoretic techniques", "Mathematical foundations of cryptography"]},
            {"subdomain": "Formal methods and theory of security", "examples": ["Trust frameworks", "Security requirements", "Formal security models", "Logic and verification"]},
            {"subdomain": "Security services", "examples": ["Authentication", "Access control", "Pseudonymity, anonymity and untraceability", "Privacy-preserving protocols", 
            "Digital rights management", "Authorization"]},
            {"subdomain": "Intrusion/anomaly detection and malware mitigation", "examples": ["Malware and its mitigation", "Intrusion detection systems", "Social engineering attacks"]},
            {"subdomain": "Security in hardware", "examples": ["Tamper-proof and tamper-resistant designs", "Embedded systems security", "Hardware security implementation", 
            "Hardware attacks and countermeasures", "Hardware reverse engineering"]},
            {"subdomain": "Systems security", "examples": ["Operating systems security", "Browser security", "Distributed systems security", "Information flow control", 
            "Denial-of-service attacks", "Firewalls", "Vulnerability management", "File system security"]},
            {"subdomain": "Network security", "examples": ["Security protocols", "Web protocol security", "Mobile and wireless security", "Denial-of-service attacks", "Firewalls"]},
            {"subdomain": "Database and storage security", "examples": ["Data anonymization and sanitization", "Management and querying of encrypted data", 
            "Information accountability and usage control", "Database activity monitoring"]},
            {"subdomain": "Software and application security", "examples": ["Software security engineering", "Web application security", "Social network security and privacy",
            "Domain-specific security and privacy architectures", "Software reverse engineering"]},
            {"subdomain": "Human and societal aspects of security and privacy", "examples": ["Economics of security and privacy", "Social aspects of security and privacy",
            "Privacy protections", "Usability in security and privacy"]}
        ]
    },
    {
        "high_level_domain": "Human-centered computing",
        "subdomains": [
            {"subdomain": "Human computer interaction (HCI)", "examples": ["HCI design and evaluation methods", "Interaction paradigms", "Interaction devices", "HCI theory, concepts and models", "Interaction techniques", "Interactive systems and tools", "Empirical studies in HCI"]},
            {"subdomain": "Interaction design", "examples": ["Interaction design process and methods", "Interaction design theory, concepts and paradigms", "Empirical studies in interaction design", "Systems and tools for interaction design"]},
            {"subdomain": "Collaborative and social computing", "examples": ["Collaborative and social computing theory, concepts and paradigms", "Collaborative and social computing design and evaluation methods", "Collaborative and social computing systems and tools", "Empirical studies in collaborative and social computing", "Collaborative and social computing devices"]},
            {"subdomain": "Ubiquitous and mobile computing", "examples": ["Ubiquitous and mobile computing theory, concepts and paradigms", "Ubiquitous and mobile computing systems and tools", "Ubiquitous and mobile devices", "Ubiquitous and mobile computing design and evaluation methods", "Empirical studies in ubiquitous and mobile computing"]},
            {"subdomain": "Visualization", "examples": ["Visualization techniques", "Visualization application domains", "Visualization systems and tools", "Visualization theory, concepts and paradigms", "Empirical studies in visualization", "Visualization design and evaluation methods"]},
            {"subdomain": "Accessibility", "examples": ["Accessibility theory, concepts and paradigms", "Empirical studies in accessibility", "Accessibility design and evaluation methods", "Accessibility technologies", "Accessibility systems and tools"]}
        ]
    },
    {
        "high_level_domain": "Applied computing",
        "subdomains": [
            {"subdomain": "Electronic commerce", "examples": ["Digital cash", "E-commerce infrastructure", "Electronic data interchange", "Electronic funds transfer", "Online shopping", "Online banking", "Secure online transactions", "Online auctions"]},
            {"subdomain": "Enterprise computing", "examples": ["Enterprise information systems", "Business process management", "Enterprise architectures", "Service-oriented architectures", "Event-driven architectures", "Business rules", "Enterprise modeling", "Enterprise ontologies, taxonomies and vocabularies", "Enterprise data management", "Reference models", "Business-IT alignment", "IT architectures", "IT governance", "Enterprise computing infrastructures", "Enterprise interoperability"]},
            {"subdomain": "Physical sciences and engineering", "examples":["Aerospace", "Archaeology", "Astronomy", "Chemistry", "Earth and atmospheric sciences", "Engineering", "Physics"]},
            {"subdomain": "Life and medical sciences", "examples": ["Computational biology", "Genomics", "Systems biology", "Consumer health", "Health care information systems", "Health informatics", "Bioinformatics", "Metabolomics / metabonomics", "Genetics"]},
            {"subdomain": "Law, social and behavioral sciences", "examples": ["Anthropology", "Law", "Psychology", "Economics", "Sociology"]},
            {"subdomain": "Computer forensics", "examples": ["Surveillance mechanisms", "Investigation techniques", "Evidence collection, storage and analysis", "Network forensics", "System forensics", "Data recovery"]},
            {"subdomain": "Arts and humanities", "examples": ["Fine arts", "Performing arts", "Architecture (buildings)", "Language translation", "Media arts", "Sound and music computing"]},
            {"subdomain": "Computers in other domains", "examples": ["Digital libraries and archives", "Publishing", "Military", "Cartography", "Agriculture", "Computing in government", "Personal computers and PC applications"]},
            {"subdomain": "Operations research", "examples": ["Consumer products", "Industry and manufacturing", "Computer-aided manufacturing", "Decision analysis", "Transportation", "Forecasting", "Marketing"]},
            {"subdomain": "Education", "examples": ["Digital libraries and archives", "Computer-assisted instruction", "Interactive learning environments", "Collaborative learning", "Learning management systems", "Distance learning", "E-learning", "Computer-managed instruction"]},
            {"subdomain": "Document management and text processing", "examples": ["Document searching", "Document management", "Document capture", "Document preparation"]},

        ]
    },
    {
        "high_level_domain": "Mathematics of computing",
        "subdomains": [
            {"subdomain": "Discrete mathematics", "examples": ["Combinatorics", "Graph theory"]},
            {"subdomain": "Probability and statistics", "examples": ["Probabilistic representations","Probabilistic inference problems","Probabilistic reasoning algorithms", "Probabilistic algorithms", "Statistical paradigms", "Stochastic processes", "Nonparametric statistics", "Distribution functions", "Multivariate statistics"]},
            {"subdomain": "Mathematical software", "examples": ["Solvers", "Statistical software", "Mathematical software performance"]},
            {"subdomain": "Information theory","examples": ["Coding theory"]},
            {"subdomain": "Mathematical analysis", "examples": ["Numerical analysis", "Mathematical optimization", "Differential equations", "Calculus", "Functional analysis", "Integral equations", "Nonlinear equations", "Quadrature"]},
            {"subdomain": "Continuous mathematics", "examples": ["Calculus", "Topology", "Continuous functions"]}
        ]
    },
    {
        "high_level_domain": "Theory of computation",
        "subdomains": [
            {"subdomain": "Models of computation", "examples": ["Computability", "Probabilistic computation", "Quantum computation theory", "Interactive computation", "Streaming models", "Concurrency", "Timed and hybrid models", "Abstract machines"]},
            {"subdomain": "Formal languages and automata theory", "examples": ["Formalisms", "Automata over infinite objects", "Grammars and context-free languages", "Tree languages", "Automata extensions", "Regular languages"]},
            {"subdomain": "Computational complexity and cryptoraphy", "examples": ["Problems, reductions and completeness", "Communication complexity", "Circuit complexity", "Oracles and decision trees", "Algebraic complexity theory", "Quantum complexity theory", "Proof complexity", "Interactive proof systems", "Complexity theory and logic", "Cryptographic primitives", "Cryptographic protocols"]},
            {"subdomain": "Logic", "examples":["Logic and verification", "Proof theory", "Modal and temporal logics", "Automated reasoning", "Constraint and logic programming", "Constructive mathematics", "Description logics", "Equational logic and rewriting", "Finite Model Theory", "Higher order logic", "Linear logic", "Programming logic", "Abstraction", "Verification by model checking", "Type theory", "Hoare logic", "Separation logic"]},
            {"subdomain": "Design and analysis of algorithms", "examples": ["Graph algorithms analysis", "Approximation algorithms analysis", "Mathematical optimization", "Data structures design and analysis", "Online algorithms", "Parameterized complexity and exact algorithms", "Streaming, sublinear and near linear time algorithms", "Parallel algorithms", "Distributed algorithms", "Algorithm design techniques", "Concurrent algorithms"]},
            {"subdomain": "Randomness, geometry and discrete structures", "examples": ["Pseudorandomness and derandomization", "Computational geometry", "Generating random combinatorial structures", "Random walks and Markov chains", "Expander graphs and randomness extractors", "Error-correcting codes", "Random projections and metric embeddings", "Random network models", "Random search heuristics"]},
            {"subdomain": "Semantics and reasoning", "examples": ["Program constructs", "Program semantics", "Program reasoning"]}

        ]
    },
    {
        "high_level_domain": "Computing methodologies",
        "subdomains": [
            {"subdomain": "Symbolic and algebraic manipulation", "examples": ["Symbolic and algebraic algorithms", "Computer algebra systems", "Representation of mathematical objects"]},
            {"subdomain": "Parallel computing methodologies", "examples": ["Parallel algorithms", "Parallel programming languages"]},
            {"subdomain": "Artificial intelligence", "examples": ["Natural language processing", "Knowledge representation and reasoning", "Planning and scheduling", "Search methodologies", "Control methods", "Philosophical/theoretical foundations of artificial intelligence", "Distributed artificial intelligence", "Computer vision"]},
            {"subdomain": "Machine learning", "examples": ["Learning paradigms", "Learning settings", "Machine learning approaches", "Machine learning algorithms", "Cross-validation"]},
            {"subdomain": "Modeling and simulation", "examples": ["Model development and analysis", "Simulation theory", "Simulation types and techniques", "Simulation support systems", "Simulation evaluation"]},
            {"subdomain": "Computer graphics", "examples": ["Animation", "Rendering", "Image manipulation", "Graphics systems and interfaces", "Image compression", "Shape modeling"]},
            {"subdomain": "Distributed computing methodologies", "examples": ["Distributed algorithms", "Distributed programming languages"]},
            {"subdomain": "Concurrent computing methodologies", "examples": ["Concurrent programming languages", "Concurrent algorithms"]}
        ]
    },
    {
    
        "high_level_domain": "Social and professional topics",
        "subdomains": [
            {"subdomain": "Professional topics", "examples": ["Computing industry", "Management of computing and information systems", "History of computing", "Computing education", "Computing and business", "Computing profession"]},
            {"subdomain": "Computing / technology policy", "examples": ["Intellectual property", "Privacy policies", "Censorship", "Surveillance", "Commerce policy", "Network access control", "Computer crime", "Government technology policy", "Medical information policy"]},
            {"subdomain": "User characteristics", "examples": ["Race and ethnicity", "Religious orientation", "Gender", "Sexual orientation", "People with disabilities", "Geographic characteristics", "Cultural characteristics", "Age"]}
        ]
    }
]

acm_json = json.dumps(acm_ccs_structure, indent=4)

# %%
def build_sub_subdomain_map(acm_structure):
    mapping = {}
    for domain in acm_structure:
        high_domain = domain["high_level_domain"]
        for sub in domain["subdomains"]:
            subdomain = sub["subdomain"]
            for example in sub.get("examples", []):
                mapping[example.lower()] = {"high_level_domain": high_domain, "subdomain": subdomain}
    return mapping

# %%
def generate_system_prompt(paper, task):
    title = paper['title']
    content = paper['content']

    if task == "title":
        return f"""
        You are tasked with extracting the title of the provided cybersecurity paper.

        Guidelines:
        \t1. The title is often at the top of the first page.
        \t2. Extract the title in its entirety.

        Here is the paper content:
        <Start of Paper Content>
        {content}
        <End of Paper Content>

        Your response must be returned in the following JSON format:
        {{
            "title": "Title of the paper here"
        }}

        Your response: """
    
    elif task == "conference_name":
         
         return f"""
        You are tasked with extracting the conference name where the paper was presented.
        
        Guidelines:
        \t1. The conference name is usually found at the top or bottom of the first page.
        \t2. Use the short form (USS, NDSS, ACSAC, SP, CCS) if applicable.
        
        Here is the paper content:
        <Start of Paper Content>
        {content}
        <End of Paper Content>
        
        Your response must be returned in the following JSON format:
        {{
            "conference": "Short form of conference name (USS, NDSS, ACSAC, SP, CCS)"
        }}

        Your response: """

    elif task == "published_year":
        return f"""
        You are tasked with extracting the year of publication from the provided cybersecurity paper.
        
        Guidelines:
        \t1. The year of publication is usually found near the conference name or at the bottom of the first page.
        
        Here is the paper content:
        <Start of Paper Content>
        {content}
        <End of Paper Content>
        
        Your response must be returned in the following JSON format:
        {{
            "year": "Year of publication here"
        }}
        
        Your response: """

   

    elif task == "domain":
        acm_json = json.dumps(acm_ccs_structure, indent=4)

        subdomain_map = {}
        for domain in acm_ccs_structure:
            for sub in domain["subdomains"]:
                for example in sub.get("examples", []):
                    subdomain_map[example] = {
                        "high_level_domain": domain["high_level_domain"],
                        "subdomain": sub["subdomain"]
                    }
        flat_map_json = json.dumps(subdomain_map, indent=4)

        return f"""
        You are tasked with identifying the **ACM Computing Classification System (CCS)** research domains for the following cybersecurity paper titled: \"{title}\".

        Your job is to return the correct **\"high_level_domain\"** and its corresponding **\"subdomain\"**, based on the paper’s content and the ACM CCS structure
        provided below.

         Guideline:
         t1. **Strictly follow the ACM CCS structure** below.
         \t- For each domain, you MUST use:
         \t- **high_level_domain**: One of the official ACM categories (e.g., "Security and privacy").
         \t- **subdomain**: Choose ONLY from the subdomains under the high-level domain as defined in the ACM structure.
         
         t2. Never invent sub-subdomains. The ACM CCS structure you are given ends at the subdomain level.
         \t- Even if the paper mentions a sub-subdomain (like "Usability in security and privacy"), your job is to **map it to the correct subdomain**
         from the ACM structure.
         \t- Use the mapping guide provided below under <SUB_SUBDOMAIN_MAPPING> to assist with this mapping task.
        
         t3. You are allowed to return **multiple (high_level_domain, subdomain)** pairs if the paper covers more than one domain.
         t4. Special Rule for NDSS / USENIX Security / IEEE S&P:
         \t- If the conference is **NDSS**, **USENIX Security**, or **IEEE S&P**, always treat the main high-level domain as "Security and privacy" (if relevant)
         \t  and identify the correct **subdomain** based on the paper content (typically "Network security" or "Systems security", etc.).

         t5. Special Rule for ACM CCS and ACSAC:
         \t- If the venue is **ACM CCS** or **ACSAC**, you should primarily determine the domain from the **"CCS Concepts"** section that appears on the first page.
         \t- Read the CCS Concepts block and map the listed CCS terms to the closest (high_level_domain, subdomain) pairs in the ACM CCS structure.
         \t- Only fall back to scanning the rest of the paper if the CCS Concepts section is missing or too generic to classify.
        
         Json Output Examples:
         Example #1 : For the paper titled **"(Un)informed Consent: Studying GDPR Consent Notices in the Field"** with the following CCS concepts:

         • Security and privacy → Usability in security and privacy
         • Human-centered computing → Empirical studies in interaction design
         • Social and professional topics → Government technology policy

         You should respond with:

         ```json
         [
           {{
             "high_level_domain": "Security and privacy",
             "subdomain": "Human and societal aspects of security and privacy"
           }},
           {{
             "high_level_domain": "Human-centered computing",
             "subdomain": "Interaction design"
           }},
           {{
             "high_level_domain": "Social and professional topics",
             "subdomain": "Computing / technology policy"
           }}
         ]
         ```

         Here is the full ACM CCS structure:
         <ACM_CCS_START>
         {acm_json}
         <ACM_CCS_END>

         Sub-subdomain mapping to subdomains:
         <SUB_SUBDOMAIN_MAPPING>
         {flat_map_json}
         <SUB_SUBDOMAIN_MAPPING_END>

         Start of Paper Content:
         {content}
         End of Paper Content:

         Your response:"""
        
        return f"Error: Task '{task}' is not supported"

# %%
def load_papers_from_jsonl(filepath):
    papers = []
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            papers.append(json.loads(line.strip()))
    return papers

def save_incremental_results(results, output_file="acm_results_incremental.jsonl"):
    with open(output_file, "a", encoding="utf-8") as file:
        for paper_title, result in results.items():
            file.write(json.dumps({paper_title: result}) + "\n")

def load_saved_results(output_file="acm_results_incremental.jsonl"):
    saved_titles = set()
    saved_results = {}
    try:
        with open(output_file, "r", encoding="utf-8") as file:
            for line in file:
                result = json.loads(line.strip())
                for title, data in result.items():
                    saved_titles.add(title)
                    saved_results[title] = data
    except FileNotFoundError:
        print("No previous results found.")
    return saved_titles, saved_results

# %%
def process_acm_domain_task(
    papers,
    start_index=0,
    output_file="acm_results_incremental.jsonl"
):
    """
    Runs four tasks per paper using GPT-5.1 models:
      - title
      - conference_name
      - published_year
      - domain

    Uses incremental saving so you can resume.
    """
    task_results = {}

    # Load already processed titles from previous runs
    processed_titles, _ = load_saved_results(output_file)

    # You can tune models per task if you want
    TASK_MODELS = {
        "title": "gpt-4o-mini",
        "conference_name": "gpt-4o-mini",
        "published_year": "gpt-4o-mini",
        "domain": "gpt-5.1",   # domain is a bit harder → use full model
    }

    tasks = ["title", "conference_name", "published_year", "domain"]

    for i, paper in enumerate(papers, start=start_index):
        title = paper.get("title", "").strip()
        if not title:
            print(f"Skipping paper {i + 1}: missing title")
            continue

        if title in processed_titles:
            print(f"Skipping already processed paper: {title}")
            continue

        print(f"Processing paper {i + 1}/{len(papers)}: {title}")
        task_results[title] = {}

        for task in tasks:
            prompt = generate_system_prompt(paper, task)
            model_name = TASK_MODELS.get(task, "gpt-5.1-mini")

            try:
                response = client.chat.completions.create(
                    model=model_name,
                    messages=[{"role": "user", "content": prompt}],
                    temperature=0.0,
                    max_completion_tokens=800,
                )
                result = response.choices[0].message.content
                print(f"  {task} done")
                task_results[title][task] = result

            except Exception as e:
                print(f"  Error{task}: {e}")
                task_results[title][task] = f"error: {str(e)}"

        # Save incremental results after each paper
        save_incremental_results({title: task_results[title]}, output_file)

    return task_results

# %%
jsonl_path = "papers_extracted.jsonl"
papers = load_papers_from_jsonl(jsonl_path)

results = process_acm_domain_task(papers)
# Out:
# Skipping already processed paper: (Un)informed Consent  Studying GDPR Consent Notices in the Field.
# Skipping already processed paper: (Un)linkable Pseudonyms for Governmental Databases.
# Skipping already processed paper: -programme oblivisync-practical-oblivious-file-backup-and-synchronization
# Skipping already processed paper: 00SEVen Re enabling Virtual Machine Forensics Introspecting Confidential VMs Using Privileged in VM Agents
# Skipping already processed paper: 1 Trillion Dollar Refund  How To Spoof PDF Signatures.
# Skipping already processed paper: 27 Years and 81 Million Opportunities Later Investigating the Use of Email Encryption for an Entire University
# Skipping already processed paper: 28 Blinks Later  Tackling Practical Challenges of Eye Movement Biometrics.
# Skipping already processed paper: 50 Shades of Support A Device Centric Analysis of Android Security Updates
# Skipping already processed paper: 50 Ways to Leak Your Data An Exploration of Apps Circumvention of the Android Permissions System
# Skipping already processed paper: 5Gen-C  Multi-input Functional Encryption and Program Obfuscation for Arithmetic Circuits.
# Skipping already processed paper: 5Gen  A Framework for Prototyping Applications Using Multilinear Maps and Matrix Branching Programs.
# Skipping already processed paper: 5GReasoner  A Property-Directed Security and Privacy Analysis Framework for 5G Cellular Network Protocol.
# Skipping already processed paper: 5G Spector An O RAN Compliant Layer 3 Cellular Attack Detection Service
# Skipping already processed paper: 6Sense Internet Wide IPv6 Scanning and its Security Applications
# Skipping already processed paper: 6thSense A Context aware Sensor based Attack Detector for Smart Devices
# Skipping already processed paper: 99 False Positives A Qualitative Study of SOC Analysts Perspectives on Security Alarms
# Skipping already processed paper: A 2.1 KHz Zero-Knowledge Processor with BubbleRAM.
# Skipping already processed paper: A Better Method to Analyze Blockchain Consistency.
# Skipping already processed paper: A Comprehensive Formal Security Analysis of OAuth 2.0.
# Skipping already processed paper: A Comprehensive Symbolic Analysis of TLS 1.3.
# Skipping already processed paper: A Concrete Treatment of Efficient Continuous Group Key Agreement via Multi-Recipient PKEs
# Skipping already processed paper: A Cryptographic Analysis of the TLS 1.3 Handshake Protocol Candidates.
# Skipping already processed paper: A Data-free Backdoor Injection Approach
# Skipping already processed paper: A Domain-Specific Language for Low-Level Secure Multiparty Computation Protocols.
# Skipping already processed paper: A Fast and Verified Software Stack for Secure Function Evaluation.
# Skipping already processed paper: A First Look at Toxicity Injection Attacks on Open-domain Chatbots 1
# Skipping already processed paper: A Forensically Sound Method of Identifying Downloaders and Uploaders in Freenet.
# Skipping already processed paper: A Formal Analysis of 5G Authentication.
# Skipping already processed paper: A Formal Foundation for Secure Remote Execution of Enclaves.
# Skipping already processed paper: A Formal Treatment of Accountable Proxying Over TLS.
# Skipping already processed paper: A Formal Treatment of Deterministic Wallets.
# Skipping already processed paper: A Framework for Constructing Fast MPC over Arithmetic Circuits with Malicious Adversaries and an Honest-Majority.
# Skipping already processed paper: A Generic Approach to Automatic Deobfuscation of Executable Code.
# Skipping already processed paper: A Generic Technique for Automatically Finding Defense-Aware Code Reuse Attacks.
# Skipping already processed paper: A Hard Label Black-box Adversarial Attack Against Graph Neural Networks.
# Skipping already processed paper: A Heuristic Framework to Detect Concurrency Vulnerabilities.
# Skipping already processed paper: A High-Assurance Evaluator for Machine-Checked Secure Multiparty Computation.
# Skipping already processed paper: A Large Scale Investigation of Obfuscation Use in Google Play.
# Skipping already processed paper: A Large-Scale Empirical Study of Security Patches.
# Skipping already processed paper: A Lightweight IoT Cryptojacking Detection
# Skipping already processed paper: A Lustrum of Malware Network Communication Evolution and Insights.
# Skipping already processed paper: A Machine Learning Approach to Prevent Malicious Calls over Telephony Networks.
# Skipping already processed paper: A Machine-Checked Proof of Security for AWS Key Management Service.
# Skipping already processed paper: A Measurement Study of Authentication Rate-Limiting Mechanisms of Modern Websites.
# Skipping already processed paper: A Measurement Study on Linux Container Security Attacks and Countermeasures.
# Skipping already processed paper: A Method for Verifying Privacy-Type Properties The Unbounded Case.
# Skipping already processed paper: A Multi-Modal Neuro-Physiological Study of Phishing Detection and Malware Warnings.
# Skipping already processed paper: a naïve approach is to use the International Mobile Equipment
# Skipping already processed paper: A Novel Analysis of Utility in Privacy Pipelines, Using Kronecker Products and Quantitative Information Flow
# Skipping already processed paper: A Performant, Misuse-Resistant API for Primality Testing.
# Skipping already processed paper: A PKI-based Framework for Establishing Efficient MPC Channels
# Skipping already processed paper: A Practical Oblivious Map Data Structure with Secure Deletion and History Independence.
# Skipping already processed paper: A Principled Approach for ROP Defense.
# Skipping already processed paper: A Privacy Analysis of Cross-device Tracking
# Skipping already processed paper: A Programming Framework for Differential Privacy with Accuracy Concentration Bounds.
# Skipping already processed paper: A Protocol for Privately Reporting Ad Impressions at Scale.
# Skipping already processed paper: A Qualitative Study of Dependency Management and Its Security Implications.
# Skipping already processed paper: A Robust and Efficient Defense against Use-after-Free Exploits via Concurrent Pointer Sweeping.
# Skipping already processed paper: A Run a Day Won't Keep the Hacker Away Inference Attacks on Endpoint Privacy Zones in Fitness Tracking Social Networks
# Skipping already processed paper: A Search Engine Backed by Internet-Wide Scanning.
# Skipping already processed paper: A Secure Sharding Protocol For Open Blockchains.
# Skipping already processed paper: A Semantic-Driven Approach to Field Inference for 1
# Skipping already processed paper: A Software Approach to Defeating Side Channels in Last-Level Caches.
# Skipping already processed paper: A Stealthier Partitioning Attack against Bitcoin Peer-to-Peer Network.
# Skipping already processed paper: A Stitch in Time  Supporting Android Developers in WritingSecure Code.
# Skipping already processed paper: A Surfeit of SSH Cipher Suites.
# Skipping already processed paper: A Symbolic Analysis of Privacy for TLS 1.3 with Encrypted Client Hello 1
# Skipping already processed paper: A Systematic Analysis of the Juniper Dual EC Incident.
# Skipping already processed paper: A Systematic Evaluation of Automated Tools for Side-Channel Vulnerabilities Detection in Cryptographic Libraries
# Skipping already processed paper: A Systematic Study of Elastic Objects in Kernel Exploitation.
# Skipping already processed paper: A Tale of Evil Twins  Adversarial Inputs versus Poisoned Models.
# Skipping already processed paper: A Tale of Sea and Sky On the Security of Maritime VSAT Communications.
# Skipping already processed paper: A Tale of Two Worlds  Assessing the Vulnerability of Enclave Shielding Runtimes.
# Skipping already processed paper: A Touch of Evil High-Assurance Cryptographic Hardware from Untrusted Components.
# Skipping already processed paper: A Tough Call Mitigating Advanced Code-Reuse Attacks at the Binary Level.
# Skipping already processed paper: A Type System for Privacy Properties.
# Skipping already processed paper: A Unilateral-to-Mutual Authentication Compiler for Key Exchange (with Applications to Client Authentication in TLS 1.3).
# Skipping already processed paper: A Usability Evaluation of Let's Encrypt and Certbot  Usable Security Done Right.
# Skipping already processed paper: A11y and Privacy dont have to be mutually exclusive Constraining Accessibility Service Misuse on Android
# Skipping already processed paper: A2 Analog Malicious Hardware.
# Skipping already processed paper: A4NT Author Attribute Anonymity by Adversarial Training of Neural Machine Translation
# Skipping already processed paper: AAKA An Anti Tracking Cellular Authentication Scheme Leveraging Anonymous Credentials
# Skipping already processed paper: Aardvark An Asynchronous Authenticated Dictionary with Applications to Account based Cryptocurrencies
# Skipping already processed paper: ABACuS All Bank Activation Counters for Scalable and Low Overhead RowHammer Mitigation
# Skipping already processed paper: Abandon All Hope Ye Who Enter Here A Dynamic Longitudinal Investigation of Androids Data Safety Section
# Skipping already processed paper: ABC Enabling Smartphone Authentication with Built in Camera
# Skipping already processed paper: ABFL A Blockchain-enabled Robust Framework for Secure and Trustworthy Federated Learning 1
# Skipping already processed paper: Above and Beyond Organizational Efforts to Complement US Digital Security Compliance Mandates
# Skipping already processed paper: ABS Scanning Neural Networks for Back-doors by Artificial Brain Stimulation.
# Skipping already processed paper: ABSynthe Automatic Blackbox Side channel Synthesis on Commodity Microarchitectures
# Skipping already processed paper: Abuse Reporting for Metadata Hiding Communication Based on Secret Sharing
# Skipping already processed paper: Abuse Resistant Location Tracking Balancing Privacy and Safety in the Offline Finding Ecosystem
# Skipping already processed paper: Abuse Vectors A Framework for Conceptualizing IoT Enabled Interpersonal Abuse
# Skipping already processed paper: Abusing Hidden Properties to Attack the Nodejs Ecosystem
# Skipping already processed paper: Abusing the Ethereum Smart Contract Verification Services for Fun and Profit
# Skipping already processed paper: ABY20 Improved Mixed Protocol Secure Two Party Computation
# Skipping already processed paper: ABY3 A Mixed Protocol Framework for Machine Learning.
# Skipping already processed paper: ABY A Framework for Efficient Mixed Protocol Secure Two Party Computation
# Skipping already processed paper: ACAI Protecting Accelerator Execution with Arm Confidential Computing Architecture
# Skipping already processed paper: Accelerating Secure Collaborative Machine Learning with Protocol Aware RDMA
# Skipping already processed paper: Accept All Exploits Exploring the Security Impact of Cookie Banners
# Skipping already processed paper: Accept All Exploits Exploring the Security Impact of Cookie Banners 1
# Skipping already processed paper: Access Denied Assessing Physical Risks
# Skipping already processed paper: Accessorize to a Crime  Real and Stealthy Attacks on State-of-the-Art Face Recognition.
# Skipping already processed paper: Access Denied Assessing Physical Risks to Internet Access Networks
# Skipping already processed paper: Access Your Tesla without Your Awareness Compromising Keyless Entry System of Model 3
# Skipping already processed paper: Accountable Javascript Code Delivery
# Skipping already processed paper: Account Security Interfaces Important Unintuitive and Untrustworthy
# Skipping already processed paper: Account Verification on Social Media User Perceptions and Paid Enrollment
# Skipping already processed paper: Accuracy-Privacy Trade-off in Deep Ensemble A Membership Inference Perspective
# Skipping already processed paper: Accurate Malware Detection by Extreme Abstraction.
# Skipping already processed paper: Accurately Measuring Global Risk of Amplification Attacks using AmpMap
# Skipping already processed paper: AceDroid Normalizing Diverse Android Access Control Checks for Inconsistency Detection
# Skipping already processed paper: ACES Automatic Compartments for Embedded Systems
# Skipping already processed paper: ACE  Asynchronous and Concurrent Execution of Complex Smart Contracts.
# Skipping already processed paper: ACE A Model Poisoning Attack on Contribution Evaluation Methods in Federated Learning
# Skipping already processed paper: ACFA Secure Runtime Auditing Guaranteed Device Healing via Active Control Flow Attestation
# Skipping already processed paper: Achieving Keyless CDNs with Conclaves
# Skipping already processed paper: Acing the IOC Game Toward Automatic Discovery and Analysis of Open-Source Cyber Threat Intelligence.
# Skipping already processed paper: ACon2 Adaptive Conformal Consensus for Provable Blockchain Oracles
# Skipping already processed paper: ACORN Input Validation for Secure Aggregation
# Skipping already processed paper: Acoustics to the Rescue Physical Key Inference Attack Revisited
# Skipping already processed paper: Acoustic Keystroke Leakage on Smart Televisions
# Skipping already processed paper: Acquisitional Rule based Engine for Discovering Internet of Thing Devices
# Skipping already processed paper: Actions Speak Louder than Words Entity Sensitive Privacy Policy and Data Flow Analysis with PoliCheck
# Skipping already processed paper: ActiveDaemon Unconscious DNN Dormancy and Waking Up via User specific Invisible Token
# Skipping already processed paper: ACTOR Action Guided Kernel Fuzzing
# Skipping already processed paper: Ad Injection at Scale Assessing Deceptive Advertisement Modifications.
# Skipping already processed paper: Adapting Security Warnings to Counter Online Disinformation
# Skipping already processed paper: Adaptive Android Kernel Live Patching
# Skipping already processed paper: Adaptive Risk-Limiting Comparison Audits
# Skipping already processed paper: AdCube WebVR Ad Fraud and Practical Confinement of Third Party Ads
# Skipping already processed paper: Address Oblivious Code Reuse On the Effectiveness of Leakage Resilient Diversity
# Skipping already processed paper: ADSNARK Nearly Practical and Privacy-Preserving Proofs on Authenticated Data.
# Skipping already processed paper: Advanced Probabilistic Couplings for Differential Privacy.
# Skipping already processed paper: Advanced Windows Methods on Malware Detection and Classification.
# Skipping already processed paper: Adversarial Data Mining Big Data Meets Cyber Security.
# Skipping already processed paper: Adversarial Sensor Attack on LiDAR-based Perception in Autonomous Driving.
# Skipping already processed paper: Adversarial Training for Raw-Binary
# Skipping already processed paper: AdVersarial  Perceptual Ad Blocking meets Adversarial Machine Learning.
# Skipping already processed paper: Adversarial Attacks Against Automatic Speech Recognition Systems via Psychoacoustic Hiding
# Skipping already processed paper: Adversarial Classification Under Differential Privacy
# Skipping already processed paper: Adversarial Detection Avoidance Attacks Evaluating the robustness of perceptual hashing based client side scanning
# Skipping already processed paper: Adversarial Examples for Proof-of-Learning
# Skipping already processed paper: Adversarial Illusions in Multi Modal Embeddings
# Skipping already processed paper: Adversarial Policy Training against Deep Reinforcement Learning
# Skipping already processed paper: Adversarial Prefetch New Cross-Core Cache Side Channel Attacks
# Skipping already processed paper: Adversarial Preprocessing Understanding and Preventing Image Scaling Attacks in Machine Learning
# Skipping already processed paper: Adversarial Robustness for Tabular Data through Cost and Utility Awareness
# Skipping already processed paper: Adversarial Training for Raw Binary Malware Classifiers
# Skipping already processed paper: Adversarial Watermarking Transformer Towards Tracing Text Provenance with Data Hiding
# Skipping already processed paper: Adversary Instantiation Lower Bounds for Differentially Private Machine Learning
# Skipping already processed paper: Adversary is on the Road Attacks on Visual SLAM using Unnoticeable Adversarial Patch
# Skipping already processed paper: AdvPulse  Universal, Synchronization-free, and Targeted Audio Adversarial Attacks via Subsecond Perturbations.
# Skipping already processed paper: Aegis Mitigating Targeted Bit flip Attacks against Deep Neural Networks
# Skipping already processed paper: AEX Notify Thwarting Precise Single Stepping Attacks through Interrupt Awareness for Intel SGX Enclaves
# Skipping already processed paper: AE Morpher Improve Physical Robustness of Adversarial Objects against LiDAR based Detectors via Object Reconstruction
# Skipping already processed paper: AFLGuard Byzantine-robust Asynchronous Federated Learning 1
# Skipping already processed paper: Agamotto Accelerating Kernel Driver Fuzzing with Lightweight Virtual Machine Checkpoints
# Skipping already processed paper: Aggregate Signatures with Versatile Randomization and Issuer-Hiding Multi-Authority Anonymous Credentials
# Skipping already processed paper: Ahoy SAILR There is No Need to DREAM of C A Compiler Aware Structuring Algorithm for Binary Decompilation
# Skipping already processed paper: AI-Guardian Defeating Adversarial Attacks using Backdoors
# Skipping already processed paper: AIFORE Smart Fuzzing Based on Automatic Input Format Reverse Engineering
# Skipping already processed paper: AIM-SDN Attacking Information Mismanagement in SDN-datastores.
# Skipping already processed paper: AIML for Network Security The Emperor has no Clothes 1
# Skipping already processed paper: Aion Enabling Open Systems through Strong Availability Guarantees for Enclaves
# Skipping already processed paper: AIRS Explanation for Deep Reinforcement Learning based Security Applications
# Skipping already processed paper: AIRTAG Towards Automated Attack Investigation by Unsupervised Learning with Log Texts
# Skipping already processed paper: AI Psychiatry Forensic Investigation of Deep Learning Networks in Memory Images
# Skipping already processed paper: ALASTOR Reconstructing the Provenance of Serverless Intrusions
# Skipping already processed paper: ALchemist Fusing Application and Audit Logs for Precise Attack Provenance without Instrumentation
# Skipping already processed paper: ALCHEMY A Language and Compiler for Homomorphic Encryption Made easY.
# Skipping already processed paper: Alert Alchemy SOC Workflows and Decisions in the
# Skipping already processed paper: Algorithm Substitution Attacks from a Steganographic Perspective.
# Skipping already processed paper: Aliasing Backdoor Attacks on Pre trained Models
# Skipping already processed paper: All Your DNS Records Point to Us Understanding the Security Threats of Dangling DNS Records.
# Skipping already processed paper: All cops are broadcasting TETRA under scrutiny
# Skipping already processed paper: All of them claim to be the best Multi perspective study of VPN users and VPN providers
# Skipping already processed paper: All the Numbers are US Large scale Abuse of Contact Discovery in Mobile Messengers
# Skipping already processed paper: All Things Considered An Analysis of IoT Devices on Home Networks
# Skipping already processed paper: All Your Biases Belong to Us Breaking RC4 in WPA TKIP and TLS
# Skipping already processed paper: All Your Clicks Belong to Me Investigating Click Interception on the Web
# Skipping already processed paper: All Your GPS Are Belong To Us Towards Stealthy Manipulation of Road Navigation Systems
# Skipping already processed paper: All Your Queries Are Belong to Us The Power of File Injection Attacks on Searchable Encryption
# Skipping already processed paper: All Your Tokens are Belong to Us Demystifying Address Verification Vulnerabilities in Solidity Smart Contracts
# Skipping already processed paper: Almost Instance-optimal Clipping for Summation Problems in the Shuffle Model of Differential Privacy
# Skipping already processed paper: ALOHA Auxiliary Loss Optimization for Hypothesis Augmentation
# Skipping already processed paper: ALPACA Application Layer Protocol Confusion Analyzing and Mitigating Cracks in TLS Authentication
# Skipping already processed paper: AlphaEXP An Expert System for Identifying Security Sensitive Kernel Objects
# Skipping already processed paper: Alternative Implementations of Secure Real Numbers.
# Skipping already processed paper: AMD Prefetch Attacks through Power and Time
# Skipping already processed paper: Amortizing Secure Computation with Penalties.
# Skipping already processed paper: AmpFuzz Fuzzing for Amplification DDoS Vulnerabilities
# Skipping already processed paper: An Analysis of Pre-installed Android Software.
# Skipping already processed paper: An Empirical Study of Mnemonic Sentence-based Password Generation Strategies.
# Skipping already processed paper: An Empirical Study of Web Vulnerability Discovery Ecosystems.
# Skipping already processed paper: An End-to-End System for Large Scale P2P MPC-as-a-Service and Low-Bandwidth MPC for Weak Participants.
# Skipping already processed paper: An Experimental Security Analysis of an Industrial Robot Controller.
# Skipping already processed paper: An Exploration of ARM System-Level Cache and GPU Side Channels 1
# Skipping already processed paper: An Exploratory Analysis of Microcode as a Building Block for System Defenses.
# Skipping already processed paper: An Extensive Formal Security Analysis of the OpenID Financial-Grade API.
# Skipping already processed paper: An In-depth Look Into SDN Topology Discovery Mechanisms Novel Attacks and Practical Countermeasures.
# Skipping already processed paper: An In-Depth Study of More Than Ten Years of Java Exploitation.
# Skipping already processed paper: An In-Depth Symbolic Security Analysis of the ACME Standard 1
# Skipping already processed paper: Analysis of DTLS Implementations Using Protocol State Fuzzing
# Skipping already processed paper: Analysis of Privacy Protections in Fitness Tracking Social Networks or You can run but can you hide
# Skipping already processed paper: Analyzing and Modeling Longitudinal Security Data Promise and Pitfalls.
# Skipping already processed paper: Analyzing Information Leakage of Updates to Natural Language Models.
# Skipping already processed paper: Analyzing Subgraph Statistics from Extended Local Views with Decentralized Differential Privacy.
# Skipping already processed paper: Analyzing Ground-Truth Data of Mobile Gambling Scams
# Skipping already processed paper: Analyzing Leakage of Personally Identifiable Information in Language Models
# Skipping already processed paper: Analyzing Semantic Correctness with Symbolic Execution A Case Study on PKCS1 v15 Signature Verification
# Skipping already processed paper: Anatomization and Protection of Mobile Apps Location Privacy Threats
# Skipping already processed paper: Anatomy of a High Profile Data Breach Dissecting the Aftermath of a Crypto Wallet Case
# Skipping already processed paper: Android ION Hazard  the Curse of Customizable Memory Management System.
# Skipping already processed paper: Android on PC On the Security of End-user Android Emulators
# Skipping already processed paper: Android Root and its Providers  A Double-Edged Sword.
# Skipping already processed paper: Android Permissions Remystified A Field Study on Contextual Integrity
# Skipping already processed paper: Android SmartTVs Vulnerability Discovery via Log Guided Fuzzing
# Skipping already processed paper: Angora Efficient Fuzzing by Principled Search.
# Skipping already processed paper: AnimateDead Debloating Web Applications Using Concolic Execution
# Skipping already processed paper: Annotating Tracking and Protecting Cryptographic Secrets with CryptoMPK
# Skipping already processed paper: Anomaly Detection in the Open World Normality Shift Detection Explanation and Adaptation
# Skipping already processed paper: AnonPSI An Anonymity Assessment Framework for PSI
# Skipping already processed paper: Anonymous Multi Hop Locks for Blockchain Scalability and Interoperability
# Skipping already processed paper: Anti-Tamper Radio System-Level Tamper Detection for Computing Systems
# Skipping already processed paper: AntiFuzz Impeding Fuzzing Audits of Binary Executables
# Skipping already processed paper: Anycast Agility Network Playbooks to Fight DDoS
# Skipping already processed paper: An Analysis of Speculative Type Confusion Vulnerabilities in the Wild
# Skipping already processed paper: An Audit of Facebooks Political Ad Policy Enforcement
# Skipping already processed paper: An Efficient Design of Intelligent Network Data Plane
# Skipping already processed paper: An Empirical Analysis of Anonymity in Zcash
# Skipping already processed paper: An Empirical Study Evaluation of Modern CAPTCHAs
# Skipping already processed paper: An Empirical Study of Textual Key Fingerprint Representations
# Skipping already processed paper: An Empirical Study of Web Resource Manipulation in Real world Mobile Applications
# Skipping already processed paper: An Ever evolving Game Evaluation of Real world Attacks and Defenses in Ethereum Ecosystem
# Skipping already processed paper: An Evil Copy How the Loader Betrays You
# Skipping already processed paper: An Experimental Study of GPS Spoofing and Takeover Attacks on UAVs
# Skipping already processed paper: An Input Agnostic Hierarchical Deep Learning Framework for Traffic Fingerprinting
# Skipping already processed paper: An Interview Study on Third Party Cyber Threat Hunting Processes in the US Department of Homeland Security
# Skipping already processed paper: An Investigation of the Android Kernel Patch Ecosystem
# Skipping already processed paper: An In Depth Analysis of Disassembly on Full Scale x86x64 Binaries
# Skipping already processed paper: An In depth Analysis of Duplicated Linux Kernel Bug Reports
# Skipping already processed paper: An LLM Assisted Easy to Trigger Backdoor Attack on Code Completion Models Injecting Disguised Vulnerabilities against Strong Detection
# Skipping already processed paper: An Observational Investigation of Reverse Engineers Processes
# Skipping already processed paper: An Off Chip Attack on Hardware Enclaves via the Memory Bus
# Skipping already processed paper: An OS agnostic Approach to Memory Forensics
# Skipping already processed paper: APEX A Verified Architecture for Proofs of Execution on Remote Devices under Full Software Compromise
# Skipping already processed paper: APICraft Fuzz Driver Generation for Closed source SDK Libraries
# Skipping already processed paper: APISan Sanitizing API Usages through Semantic Cross Checking
# Skipping already processed paper: Appenzeller to Brie Efficient Zero-Knowledge Proofs for Mixed-Mode Arithmetic and Z2k
# Skipping already processed paper: Apps Trackers Privacy and Regulators A Global Study of the Mobile Tracking Ecosystem
# Skipping already processed paper: Arana Discovering and Characterizing Password Guessing Attacks in Practice
# Skipping already processed paper: Arbiter Bridging the Static and Dynamic Divide in Vulnerability Discovery on Binary Programs
# Skipping already processed paper: ARBITRAR User-Guided API Misuse Detection
# Skipping already processed paper: Arbitrum Scalable private smart contracts
# Skipping already processed paper: Arcanum Detecting and Evaluating the Privacy Risks of Browser Extensions on Web Pages and Web Content
# Skipping already processed paper: ArcEDB An Arbitrary-Precision Encrypted Database via (Amortized) Modular Homomorphic Encryption
# Skipping already processed paper: Architecting Trigger Action Platforms for Security Performance and Functionality
# Skipping already processed paper: ArchiveSafe LT Secure Long-term Archiving System
# Skipping already processed paper: ARCUS Symbolic Root Cause Analysis of Exploits in Production Systems
# Skipping already processed paper: Are There Wireless Hidden Cameras Spying on Me 1
# Skipping already processed paper: Are These Pairing Elements Correct  Automated Verification and Applications.
# Skipping already processed paper: Are we there yet An Industrial Viewpoint on Provenance-based Endpoint Detection and Response Tools 1
# Skipping already processed paper: Are anonymity-seekers just like everybody else An analysis of contributions to Wikipedia from Tor
# Skipping already processed paper: Are Consumers Willing to Pay for Security and Privacy of IoT Devices
# Skipping already processed paper: Are Privacy Dashboards Good for End Users Evaluating User Perceptions and Reactions to Googles My Activity
# Skipping already processed paper: Are these Ads Safe Detecting Hidden Attacks through the Mobile App Web Interfaces
# Skipping already processed paper: Are We There Yet On RPKIs Deployment and Security
# Skipping already processed paper: Are We There Yet Timing and Floating-Point Attacks on Differential Privacy Systems
# Skipping already processed paper: Are Your Sensitive Attributes Private Novel Model Inversion Attribute Inference Attacks on Classification Models
# Skipping already processed paper: Are You Going to Answer That Measuring User Responses to Anti Robocall Application Indicators
# Skipping already processed paper: Are You Spying on Me Large Scale Analysis on IoT Data Exposure through Companion Apps
# Skipping already processed paper: Argus A Framework for Staged Static Taint
# Skipping already processed paper: Argus All your PHP Injection sinks are belong to us
# Skipping already processed paper: ARGUS A Framework for Staged Static Taint Analysis of GitHub Workflows and Actions
# Skipping already processed paper: ARGUS Context Based Detection of Stealthy IoT Infiltration Attacks
# Skipping already processed paper: Ariadne A Minimal Approach to State Continuity
# Skipping already processed paper: ARI Attestation of Real time Mission Execution Integrity
# Skipping already processed paper: ARMageddon Cache Attacks on Mobile Devices
# Skipping already processed paper: ARMore Pushing Love Back Into Binaries
# Skipping already processed paper: ARunaDayWon’tKeeptheHackerAwayInference Attacks on
# Skipping already processed paper: Asking for a Friend Evaluating Response Biases in Security User Studies.
# Skipping already processed paper: Asking for a Friend  Evaluating Response Biases in Security User Studies.
# Skipping already processed paper: ASLR-Guard Stopping Address Space Leakage for Code Reuse Attacks.
# Skipping already processed paper: ASLR on the Line Practical Cache Attacks on the MMU
# Skipping already processed paper: Assessing Model-free Anomaly Detection in Industrial Control Systems Against Generic Concealment Attacks 1
# Skipping already processed paper: Assessing Anonymity Techniques Employed in German Court Decisions A De Anonymization Experiment
# Skipping already processed paper: Assessing Browser level Defense against IDN based Phishing
# Skipping already processed paper: Assessing Suspicious Emails with Banner Warnings Among Blind and Low Vision Users in Realistic Settings
# Skipping already processed paper: Assessing the Impact of Interface Vulnerabilities in Compartmentalized Software
# Skipping already processed paper: ASSET Robust Backdoor Data Detection Across a Multiplicity of Deep Learning Paradigms
# Skipping already processed paper: Asynchronous Data Dissemination and its Applications 1
# Skipping already processed paper: Asynchronous Distributed Key Generation for Computationally-Secure Randomness, Consensus, and Threshold Signatures.
# Skipping already processed paper: Asynchronous Remote Key Generation  An Analysis of Yubico's Proposal for W3C WebAuthn.
# Skipping already processed paper: As Strong As Its Weakest Link How to Break Blockchain DApps at RPC Service
# Skipping already processed paper: Athena Analyzing and Quantifying Side Channels of Transport Layer Protocols
# Skipping already processed paper: ATLAS A Sequence based Learning Approach for Attack Investigation
# Skipping already processed paper: Atomic Multi-Channel Updates with Constant Collateral in Bitcoin-Compatible Payment-Channel Networks.
# Skipping already processed paper: Atropos Effective Fuzzing of Web Applications for Server Side Vulnerabilities
# Skipping already processed paper: ATTACK2VEC Leveraging Temporal Word Embeddings to Understand the Evolution of Cyberattacks
# Skipping already processed paper: AttackGNN Red Teaming GNNs in Hardware Security Using Reinforcement Learning
# Skipping already processed paper: Attacking Graph-based Classification via Manipulating the Graph Structure.
# Skipping already processed paper: Attacking Graph-Based Classification without Changing Existing Connections.
# Skipping already processed paper: Attacking OpenSSL Implementation of ECDSA with a Few Signatures.
# Skipping already processed paper: Attacking the Brain Races in the SDN Control Plane
# Skipping already processed paper: Attacking the Network Time Protocol
# Skipping already processed paper: Attacks are Forwarded Breaking the Isolation of MicroVM based Containers Through Operation Forwarding
# Skipping already processed paper: Attacks as Defenses Designing Robust Audio CAPTCHAs Using Attacks on Automatic Speech Recognition Systems
# Skipping already processed paper: Attacks Only Get Better Password Recovery Attacks Against RC4 in TLS
# Skipping already processed paper: Attacks on Deidentifications Defenses
# Skipping already processed paper: Attack Patterns for Black Box Security Testing of Multi Party Web Applications
# Skipping already processed paper: ATTention Please An Investigation of the App Tracking Transparency Permission
# Skipping already processed paper: ATtention Spanned Comprehensive Vulnerability Analysis of AT Commands Within the Android Ecosystem
# Skipping already processed paper: ATTEQ NN Attention based QoE aware Evasive Backdoor Attacks
# Skipping already processed paper: Attribute-Based Encryption in the Generic Group Model Automated Proofs and New Constructions.
# Skipping already processed paper: Attribute-based Key Exchange with General Policies.
# Skipping already processed paper: Attributions for ML based ICS Anomaly Detection From Theory to Practice
# Skipping already processed paper: AttriGuard A Practical Defense Against Attribute Inference Attacks via Adversarial Machine Learning
# Skipping already processed paper: ATTRITION Attacking Static Hardware Trojan Detection Techniques Using Reinforcement Learning
# Skipping already processed paper: AUDACIOUS  User-Driven Access Control with Unmodified Operating Systems.
# Skipping already processed paper: Auditing Frameworks Need Resource Isolation A Systematic Study on the Super Producer Threat to System Auditing and Its Mitigation
# Skipping already processed paper: Auditing Framework APIs via Inferred App side Security Specifications
# Skipping already processed paper: Auditory Eyesight Demystifying μs Precision Keystroke Tracking Attacks on Unconstrained Keyboard Inputs
# Skipping already processed paper: Augmenting Decompiler Output with Learned Variable Names and Types
# Skipping already processed paper: Augur Internet-Wide Detection of Connectivity Disruptions.
# Skipping already processed paper: Augury Using Data Memory-Dependent Prefetchers to Leak Data at Rest
# Skipping already processed paper: AURC Detecting Errors in Program Code and Documentation
# Skipping already processed paper: AURORA Statistical Crash Analysis for Automated Root Cause Explanation
# Skipping already processed paper: AuthentiCall Efficient Identity and Content Authentication for Phone Calls
# Skipping already processed paper: Authenticated Garbling and Efficient Maliciously Secure Two-Party Computation.
# Skipping already processed paper: Authenticated Network Time Synchronization
# Skipping already processed paper: Authenticated private information retrieval
# Skipping already processed paper: Authenticating Privately over Public Wi-Fi Hotspots.
# Skipping already processed paper: AuthentiSense A Scalable Behavioral Biometrics Authentication Scheme using Few Shot Learning for Mobile Platforms
# Skipping already processed paper: AuthLoop End to End Cryptographic Authentication for Telephony over Voice Channels
# Skipping already processed paper: AUTHSCOPE  Towards Automatic Discovery of Vulnerable Authorizations in Online Services.
# Skipping already processed paper: AutoDA Automated Decision based Iterative Adversarial Attacks
# Skipping already processed paper: AutoFHE Automated Adaption of CNNs for Efficient Evaluation over FHE
# Skipping already processed paper: AutoFR Automated Filter Rule Generation for Adblocking
# Skipping already processed paper: autofz Automated Fuzzer Composition at Runtime
# Skipping already processed paper: AutoLock Why Cache Attacks on ARM Are Harder Than You Think
# Skipping already processed paper: Automata Based Automated Detection of State Machine Bugs in Protocol Implementations
# Skipping already processed paper: Automata Guided Control Flow Sensitive Fuzz Driver Generation
# Skipping already processed paper: Automated Analysis and Synthesis of Authenticated Encryption Schemes.
# Skipping already processed paper: Automated Bug Hunting With Data-Driven Symbolic Root Cause Analysis 1
# Skipping already processed paper: Automated Crowdturfing Attacks and Defenses in Online Review Systems.
# Skipping already processed paper: Automated Privacy Policy Annotation with Information Highlighting Made Practical Using Deep Representations
# Skipping already processed paper: Automated Proofs of Pairing-Based Cryptography.
# Skipping already processed paper: Automated Symbolic Proofs of Observational Equivalence.
# Skipping already processed paper: Automated Synthesis of Optimized Circuits for Secure Computation.
# Skipping already processed paper: Automated Analysis of Privacy Requirements for Mobile Apps
# Skipping already processed paper: Automated Analysis of Protocols that use Authenticated Encryption How Subtle AEAD Differences can impact Protocol Security
# Skipping already processed paper: Automated Attack Discovery in TCP Congestion Control Using a Model guided Approach
# Skipping already processed paper: Automated Cookie Notice Analysis and Enforcement
# Skipping already processed paper: Automated Cross Platform Reverse Engineering of CAN Bus Commands From Mobile Apps
# Skipping already processed paper: Automated Detection of Automated Traffic
# Skipping already processed paper: Automated Discovery of Cross Plane Event Based Vulnerabilities in Software Defined Networking
# Skipping already processed paper: Automated Discovery of Denial of Service Vulnerabilities in Connected Vehicle Protocols
# Skipping already processed paper: Automated Exploitable Heap Layout Generation for Heap Overflows Through Manipulation Distance Guided Fuzzing
# Skipping already processed paper: Automated Generation of Event Oriented Exploits in Android Hybrid Apps
# Skipping already processed paper: Automated Inference on Financial Security of Ethereum Smart Contracts
# Skipping already processed paper: Automated Large Scale Analysis of Cookie Notice Compliance
# Skipping already processed paper: Automated Security Analysis of Exposure Notification Systems
# Skipping already processed paper: Automated Side Channel Analysis of Media Software with Manifold Learning
# Skipping already processed paper: Automated Synthesis of Semantic Malware Signatures using Maximum Satisfiability
# Skipping already processed paper: Automated Website Fingerprinting through Deep Learning
# Skipping already processed paper: Automatic Fingerprinting of Vulnerable BLE IoT Devices with Static UUIDs from Mobile Apps.
# Skipping already processed paper: Automatic Inference of Search Patterns for Taint-Style Vulnerabilities.
# Skipping already processed paper: Automatic Uncovering of Hidden Behaviors From Input Validation in Mobile Apps.
# Skipping already processed paper: Automatically Detecting Bystanders in Photos to Reduce Privacy Risks.
# Skipping already processed paper: Automatically Detecting Error Handling Bugs Using Error Specifications
# Skipping already processed paper: Automatically Evading Classifiers A Case Study on PDF Malware Classifiers
# Skipping already processed paper: Automatic Adversarial Adaption for Stealthy Poisoning Attacks in Federated Learning
# Skipping already processed paper: Automatic Extraction of Secrets from the Transistor Jungle using Laser Assisted Side Channel Attacks
# Skipping already processed paper: Automatic Firmware Emulation through Invalidity guided Knowledge Inference
# Skipping already processed paper: Automatic Forgery of Cryptographically Consistent Messages to Identify Security Vulnerabilities in Mobile Services
# Skipping already processed paper: Automatic Generation of Data Oriented Exploits
# Skipping already processed paper: Automatic Heap Layout Manipulation for Exploitation
# Skipping already processed paper: Automatic Hot Patch Generation for Android Kernels
# Skipping already processed paper: Automatic Policy Generation for Inter Service Access Control of Microservices
# Skipping already processed paper: Automatic Policy Synthesis and Enforcement for Protecting Untrusted Deserialization
# Skipping already processed paper: Automatic Techniques to Systematically Discover New Heap Exploitation Primitives
# Skipping already processed paper: Automating Fast and Secure Translations from Type-I to Type-III Pairing Schemes.
# Skipping already processed paper: Automating Cookie Consent and GDPR Violation Detection
# Skipping already processed paper: Automating Patching of Vulnerable Open Source Software Versions in Application Binaries
# Skipping already processed paper: Automating the Development of Chosen Ciphertext Attacks
# Skipping already processed paper: AUTOREB  Automatically Understanding the Review-to-Behavior Fidelity in Android Applications.
# Skipping already processed paper: AVA Inconspicuous Attribute Variation-based Adversarial Attack bypassing DeepFake Detection
# Skipping already processed paper: Avoiding The Man on the Wire Improving Tors Security with Trust Aware Path Selection
# Skipping already processed paper: Awakening the Webs Sleeper Agents Misusing Service Workers for Privacy Leakage
# Skipping already processed paper: AWare Preventing Abuse of Privacy Sensitive Sensors via Operation Bindings
# Skipping already processed paper: A Bad Dream Subverting Trusted Platform Module While You Are Sleeping
# Skipping already processed paper: A Billion Open Interfaces for Eve and Mallory MitM DoS and Tracking Attacks on iOS and macOS Through Apple Wireless Direct Link
# Skipping already processed paper: A Binary level Thread Sanitizer or Why Sanitizing on the Binary Level is Hard
# Skipping already processed paper: A Broad Comparative Evaluation of Software Debloating Tools
# Skipping already processed paper: A Broad View of the Ecosystem of Socially Engineered Exploit Documents
# Skipping already processed paper: A Bugs Life Analyzing the Lifecycle and Mitigation Process of Content Security Policy Bugs
# Skipping already processed paper: A Call to ARMs Understanding the Costs and Benefits of JIT Spraying Mitigations
# Skipping already processed paper: A comprehensive formal and automated analysis of the EDHOC protocol
# Skipping already processed paper: A Comprehensive Measurement Study of Domain Generating Malware
# Skipping already processed paper: A Comprehensive Quality Evaluation of Security and Privacy Advice on the Web
# Skipping already processed paper: A Data free Backdoor Injection Approach in Neural Networks
# Skipping already processed paper: A Decade of Privacy Relevant Android App Reviews Large Scale Trends
# Skipping already processed paper: A Devil of a Time How Vulnerable is NTP to Malicious Timeservers
# Skipping already processed paper: A different cup of TI The added value of commercial threat intelligence
# Skipping already processed paper: A Duty to Forget a Right to be Assured Exposing Vulnerabilities in Machine Unlearning Services
# Skipping already processed paper: A First Look at Zoombombing
# Skipping already processed paper: A First Physical World Trajectory Prediction Attack via LiDAR induced Deceptions in Autonomous Driving
# Skipping already processed paper: A Flushing Attack on the DNS Cache
# Skipping already processed paper: A Formal Analysis of IEEE 80211s WPA2 Countering the Kracks Caused by Cracking the Counters
# Skipping already processed paper: A Formal Analysis of SCTP Attack Synthesis and Patch Verification
# Skipping already processed paper: A Formal Analysis of the FIDO UAF Protocol
# Skipping already processed paper: A Friends Eye is A Good Mirror Synthesizing MCU Peripheral Models from Peripheral Drivers
# Skipping already processed paper: A Hardware Software Co design for Efficient Intra Enclave Isolation
# Skipping already processed paper: A Highly Accurate Query Recovery Attack against Searchable Encryption using Non Indexed Documents
# Skipping already processed paper: A High Coverage Cybersecurity Scale Predictive of User Behavior
# Skipping already processed paper: A Hybrid Alias Analysis and Its Application to Global Variable Protection in the Linux Kernel
# Skipping already processed paper: A Large scale Analysis of Content Modification by Open HTTP Proxies
# Skipping already processed paper: A Large scale Analysis of the Mnemonic Password Advice
# Skipping already processed paper: A Large scale and Longitudinal Measurement Study of DKIM Deployment
# Skipping already processed paper: A Large Scale Interview Study on Information Security in and Attacks against Small and Medium sized Enterprises
# Skipping already processed paper: A Large scale Investigation into Geodifferences in Mobile Apps
# Skipping already processed paper: A Large Scale Measurement of Website Login Policies
# Skipping already processed paper: A Large Scale Study of the Ethereum Arbitrage Ecosystem
# Skipping already processed paper: A Large Scale Study of User Behavior Expectations and Engagement with Android Permissions
# Skipping already processed paper: A Large scale Temporal Measurement of Android Malicious Apps Persistence Migration and Lessons Learned
# Skipping already processed paper: A Lightweight IoT Cryptojacking Detection Mechanism in Heterogeneous Smart Home Networks
# Skipping already processed paper: A Linear Reconstruction Approach for Attribute Inference Attacks against Synthetic Data
# Skipping already processed paper: A Longitudinal and Comprehensive Study of the DANE Ecosystem in Email
# Skipping already processed paper: A Longitudinal End to End View of the DNSSEC Ecosystem
# Skipping already processed paper: A Measurement Study on Co residence Threat inside the Cloud
# Skipping already processed paper: A Mixed Methods Study of Security Practices of Smart Contract Developers
# Skipping already processed paper: A Mixed Methods Study on User Experiences and Challenges of Recovery Codes for an End to End Encrypted Service
# Skipping already processed paper: A NEW HOPE Contextual Privacy Policies for Mobile Applications and An Approach Toward Automated Generation
# Skipping already processed paper: A Peek into the Metaverse Detecting 3D Model Clones in Mobile Games
# Skipping already processed paper: A Placement Vulnerability Study in Multi Tenant Public Clouds
# Skipping already processed paper: A Plot is Worth a Thousand Words Model Information Stealing Attacks via Scientific Plots
# Skipping already processed paper: A Practical Approach for Taking Down Avalanche Botnets Under Real World Constraints
# Skipping already processed paper: A Privacy Analysis of Cross device Tracking
# Skipping already processed paper: A Representative Study on Human Detection of Artificially Generated Media Across Countries
# Skipping already processed paper: A Research Framework and Initial Study of Browser Security for the Visually Impaired
# Skipping already processed paper: A Robust Counting Sketch for Data Plane Intrusion Detection
# Skipping already processed paper: A Secure and Formally Verified Linux KVM Hypervisor
# Skipping already processed paper: A Security Analysis of Honeywords
# Skipping already processed paper: A Security and Usability Analysis of Local Attacks Against FIDO2
# Skipping already processed paper: A Security Study about Electron Applications and a Programming Methodology to Tame DOM Functionalities
# Skipping already processed paper: A Sense of Time for JavaScript and Nodejs First Class Timeouts as a Cure for Event Handler Poisoning
# ...
# Skipping already processed paper: When Your Fitness Tracker Betrays You Quantifying the Predictability of Biometric Features Across Contexts.
# Skipping already processed paper: Whenthe User Is Inside the User Interface
# Skipping already processed paper: When and Why Do People Want Ad Targeting Explanations Evidence from a Four-Week Mixed-Methods Field Study
# Skipping already processed paper: When a Tree Falls Using Diversity in Ensemble Classifiers to Identify Evasion in Malware Detectors
# Skipping already processed paper: When Coding Style Survives Compilation De anonymizing Programmers from Executable Binaries
# Skipping already processed paper: When Cryptography Needs a Hand Practical Post Quantum Authentication for V2V Communications
# Skipping already processed paper: When Does Machine Learning FAIL Generalized Transferability for Evasion and Poisoning Attacks
# Skipping already processed paper: When Function Signature Recovery Meets Compiler Optimization
# Skipping already processed paper: When Malware Changed Its Mind An Empirical Study of Variable Program Behaviors in the Real World
# Skipping already processed paper: When Malware is Packin Heat Limits of Machine Learning Classifiers Based on Static Analysis Features
# Skipping already processed paper: When Match Fields Do Not Need to Match Buffered Packets Hijacking in SDN
# Skipping already processed paper: When Sally Met Trackers Web Tracking From the Users Perspective
# Skipping already processed paper: When the Signal is in the Noise Exploiting Diffixs Sticky Noise
# Skipping already processed paper: When the User Is Inside the User Interface An Empirical Study of UI Security Properties in Augmented Reality
# Skipping already processed paper: When the Weakest Link is Strong Secure Collaboration in the Case of the Panama Papers
# Skipping already processed paper: When Threads Meet Interrupts Effective Static Detection of Interrupt Based Deadlocks in Linux
# Skipping already processed paper: When Top-down Meets Bottom-up Detecting and Exploiting Use-After-Cleanup Bugs in Linux Kernel
# Skipping already processed paper: Where Does It Go  Refining Indirect-Call Targets with Multi-Layer Type Analysis.
# Skipping already processed paper: Where the Wild Warnings Are  Root Causes of Chrome HTTPS Certificate Errors.
# Skipping already processed paper: Where's Wally  Precise User Discovery Attacks in Location Proximity Services.
# Skipping already processed paper: Wheres Crypto Automated Identification and Classification of Proprietary Cryptographic Primitives in Binary Code
# Skipping already processed paper: Where to Recruit for Security Development Studies Comparing Six Software Developer Samples
# Skipping already processed paper: Which Privacy and Security Attributes Most Impact Consumers Risk Perception and Willingness to Purchase IoT Devices
# Skipping already processed paper: WHIP Improving Static Vulnerability Detection in Web Application by Forcing tools to Collaborate
# Skipping already processed paper: WhisperFuzz White Box Fuzzing for Detecting and Locating Timing Vulnerabilities in Processors
# Skipping already processed paper: White-Box Cryptography Revisited  Space-Hard Ciphers.
# Skipping already processed paper: Who is Real Bob Adversarial Attacks on Speaker Recognition Systems
# Skipping already processed paper: Who's In Control On Security Risks of Disjointed IoT Device Management Channels.
# Skipping already processed paper: Whos Calling Characterizing Robocalls through Audio and Metadata Analysis
# Skipping already processed paper: Whos Hosting the Block Party Studying Third Party Blockage of CSP and SRI
# Skipping already processed paper: Whos in Control of Your Control System Device Fingerprinting for Cyber Physical Systems
# Skipping already processed paper: Who Are You A Statistical Approach to Measuring User Authenticity
# Skipping already processed paper: Who Are You I Really Wanna Know Detecting Audio DeepFakes Through Vocal Tract Reconstruction
# Skipping already processed paper: Who Is Answering My Queries Understanding and Characterizing Interception of the DNS Resolution Path
# Skipping already processed paper: Who Left Open the Cookie Jar A Comprehensive Evaluation of Third Party Cookie Policies
# Skipping already processed paper: Why Do Developers Get Password Storage Wrong  A Qualitative Usability Study.
# Skipping already processed paper: Why Does Your Data Leak Uncovering the Data Leakage in Cloud from Mobile Apps.
# Skipping already processed paper: Why Arent We Using Passkeys Obstacles Companies Face Deploying FIDO2 Passwordless Authentication
# Skipping already processed paper: Why Crypto-detectors Fail A Systematic Evaluation of Cryptographic Misuse Detection Techniques
# Skipping already processed paper: Why Do Adversarial Attacks Transfer Explaining Transferability of Evasion and Poisoning Attacks
# Skipping already processed paper: Why Eve and Mallory Still Love Android Revisiting TLS InSecurity in Android Applications
# Skipping already processed paper: Why Older Adults Dont Use Password Managers
# Skipping already processed paper: Why TLS is better without STARTTLS A Security Analysis of STARTTLS in the Email Context
# Skipping already processed paper: Why Users Dont Use Password Managers at a Large Educational Institution
# Skipping already processed paper: Why wouldnt someone think of democracy as a target Security practices challenges of people involved with US political campaigns
# Skipping already processed paper: WI is Almost Enough  Contingent Payment All Over Again.
# Skipping already processed paper: WI Is Not Enough  Zero-Knowledge Contingent (Service) Payments Revisited.
# Skipping already processed paper: Widespread Underestimation of Sensitivity in Differentially Private Libraries and How to Fix It 1
# Skipping already processed paper: WIGHT Wired Ghost Touch Attack on Capacitive Touchscreens
# Skipping already processed paper: Wild Patterns Ten Years After the Rise of Adversarial Machine Learning.
# Skipping already processed paper: WindowGuard Systematic Protection of GUI Security in Android
# Skipping already processed paper: Windows into the Past Exploiting Legacy Crypto in Modern OSs Kerberos Implementation
# Skipping already processed paper: WINK Wireless Inference of Numerical Keystrokes via Zero-Training Spatiotemporal Analysis 1
# Skipping already processed paper: Wink Deniable Secure Messaging
# Skipping already processed paper: WINNIE Fuzzing Windows Applications with Harness Synthesis and Fast Cloning
# Skipping already processed paper: WireGuard Next Generation Kernel Network Tunnel
# Skipping already processed paper: Wireless Charging Power Side-Channel Attacks
# Skipping already processed paper: Wireless Attacks on Aircraft Instrument Landing Systems
# Skipping already processed paper: Wireless Signal Injection Attacks on VSAT Satellite Modems
# Skipping already processed paper: Withdrawing is believing Detecting Inconsistencies between Withdrawal Choices and Third-party Data Collections in Mobile Apps
# Skipping already processed paper: Withdrawing the BGP Re Routing Curtain Understanding the Security Impact of BGP Poisoning through Real World Measurements
# Skipping already processed paper: With Great Power Come Great Side Channels Statistical Timing Side Channel Analyses with Bounded Type 1 Errors
# Skipping already processed paper: With Great Training Comes Great Vulnerability Practical Attacks against Transfer Learning
# Skipping already processed paper: Wi Fly Detecting Privacy Invasion Attacks by Consumer Drones
# Skipping already processed paper: Wobfuscator Obfuscating JavaScript Malware via Opportunistic Translation to WebAssembly
# Skipping already processed paper: WooKey designing a trusted and efficient USB device.
# Skipping already processed paper: Work From Home and COVID 19 Trajectories of Endpoint Security Management in a Security Operations Center
# Skipping already processed paper: WPSE Fortifying Web Protocols via Browser Side Security Monitoring
# Skipping already processed paper: WristPrint Characterizing User Re-identification Risks from Wrist-worn Accelerometry Data 1
# Skipping already processed paper: WTAGRAPH Web Tracking and Advertising Detection using Graph Neural Networks
# Skipping already processed paper: XCheck Verifying Integrity of 3D Printed Patient Specific Devices via Computing Tomography
# Skipping already processed paper: XDA Accurate Robust Disassembly with Transfer Learning
# Skipping already processed paper: XDRI Attacks and How to Enhance Resilience of Residential Routers
# Skipping already processed paper: XFL Naming Functions in Binaries with Extreme Multi-label Learning
# Skipping already processed paper: xMP Selective Memory Protection for Kernel and User Space.
# Skipping already processed paper: xNIDS Explaining Deep Learning based Network Intrusion Detection Systems for Active Intrusion Responses
# Skipping already processed paper: XONN XNOR based Oblivious Deep Neural Network Inference
# Skipping already processed paper: Xplain Analyzing Invisible Correlations in Model Explanation
# Skipping already processed paper: XSinator.com From a Formal Model to the Automatic Evaluation of Cross-Site Leaks in Web Browsers
# Skipping already processed paper: X Adv Physical Adversarial Object Attacks against X ray Prohibited Item Detection
# Skipping already processed paper: YARIX Scalable YARA based Malware Intelligence
# Skipping already processed paper: Yes One Bit Flip Matters Universal DNN Model Inference Depletion with Runtime Code Fault Injection
# Skipping already processed paper: Yet Another Text Captcha Solver  A Generative Adversarial Network Based Approach.
# Skipping already processed paper: YODA Enabling computationally intensive contracts on blockchains with Byzantine and Selfish nodes
# Skipping already processed paper: You Are What You Do Hunting Stealthy Malware
# Skipping already processed paper: You Are Who You Appear to Be  A Longitudinal Study of Domain Impersonation in TLS Certificates.
# Skipping already processed paper: You Get Where You're Looking for The Impact of Information Sources on Code Security.
# Skipping already processed paper: You Make Me Tremble A First Look at Attacks Against Structural Control Systems
# Skipping already processed paper: You Shall Not Join A Measurement Study of Cryptocurrency Peer-to-Peer Bootstrapping Techniques.
# Skipping already processed paper: You've Changed Detecting Malicious Browser Extensions through their Update Deltas.
# Skipping already processed paper: Your Cache Has Fallen  Cache-Poisoned Denial-of-Service Attack.
# Skipping already processed paper: Your hashed IP address Ubuntu. perspectives on transparency tools for online advertising.
# Skipping already processed paper: Your Exploit is Mine Instantly Synthesizing Counterattack Smart Contract
# Skipping already processed paper: Your Firmware Has Arrived A Study of Firmware Update Vulnerabilities
# Skipping already processed paper: Your Microphone Array Retains Your Identity A Robust Voice Liveness Detection System for Smart Speakers
# Skipping already processed paper: Your Phone is My Proxy Detecting and Understanding Mobile Proxy Networks
# Skipping already processed paper: Your Router is My Prober Measuring IPv6 Networks via ICMP Rate Limiting Side Channels
# Skipping already processed paper: Youve Got Report Measurement and Security Implications of DMARC Reporting
# Skipping already processed paper: Youve Got Vulnerability Exploring Effective Vulnerability Notifications
# Skipping already processed paper: You are a Game Bot Uncovering Game Bots in MMORPGs via Self similarity in the Wild
# Skipping already processed paper: You Are What You Broadcast Identification of Mobile and IoT Devices from Public WiFi
# Skipping already processed paper: You Are What You Do Hunting Stealthy Malware via Data Provenance Analysis
# Skipping already processed paper: You Are Who You Know and How You Behave Attribute Inference Attacks via Users Social Friends and Behaviors
# Skipping already processed paper: You Autocomplete Me Poisoning Vulnerabilities in Neural Code Completion
# Skipping already processed paper: You Cannot Escape Me Detecting Evasions of SIEM Rules in Enterprise Networks
# Skipping already processed paper: You Cant See Me Physical Removal Attacks on LiDAR based Autonomous Vehicles Driving Frameworks
# Skipping already processed paper: You Can Obfuscate but You Cannot Hide CrossPoint Attacks against Network Topology Obfuscation
# Skipping already processed paper: You Can Use But Cannot Recognize Preserving Visual Privacy in Deep Neural Networks
# Skipping already processed paper: You have to read 50 different RFCs that contradict each other An Interview Study on the Experiences of Implementing Cryptographic Standards
# Skipping already processed paper: You Only Prompt Once On the Capabilities of Prompt Learning on Large Language Models to Tackle Toxic Content
# Skipping already processed paper: You Shouldnt Collect My Secrets Thwarting Sensitive Keystroke Leakage in Mobile IME Apps
# Skipping already processed paper: YPIR High Throughput Single Server PIR with Silent Preprocessing
# Skipping already processed paper: Zapper Smart Contracts with Data and Identity Privacy
# Skipping already processed paper: ZBCAN A Zero Byte CAN Defense System
# Skipping already processed paper: ZeeStar Private Smart Contracts by Homomorphic Encryption and Zero-knowledge Proofs
# Skipping already processed paper: ZenHammer Rowhammer Attacks on AMD Zen based Platforms
# Skipping already processed paper: Zero Knowledge Proofs for Decision Tree Predictions and Accuracy.
# Skipping already processed paper: Zero-Knowledge Contingent Payments Revisited  Attacks and Payments for Services.
# Skipping already processed paper: ZeroAUDIT
# Skipping already processed paper: ZeroTrace Oblivious Memory Primitives from Intel SGX
# Skipping already processed paper: Zero delay Lightweight Defenses against Website Fingerprinting
# Skipping already processed paper: Zero Knowledge Middleboxes
# Skipping already processed paper: Zero setup Intermediate rate Communication Guarantees in a Global Internet
# Skipping already processed paper: ZEUS Analyzing Safety of Smart Contracts
# Skipping already processed paper: ZigZag Automatically Hardening Web Applications Against Client side Validation Vulnerabilities
# Skipping already processed paper: zkay Specifying and Enforcing Data Privacy in Smart Contracts.
# Skipping already processed paper: zkay  Specifying and Enforcing Data Privacy in Smart Contracts.
# Skipping already processed paper: ZKBoo Faster Zero Knowledge for Boolean Circuits
# Skipping already processed paper: zkCNN Zero Knowledge Proofs for Convolutional Neural Network Predictions and Accuracy 1
# Skipping already processed paper: zkCross A Novel Architecture for Cross Chain Privacy Preserving Auditing
# Skipping already processed paper: zkSaaS Zero Knowledge SNARKs as a Service
# Skipping already processed paper: ZKSMT A VM for Proving SMT Theorems in Zero Knowledge
# Skipping already processed paper: Zombie Awakening Stealthy Hijacking of Active Domains through DNS Hosting Referral.
# Skipping already processed paper: ZombieLoad Cross-Privilege-Boundary Data Sampling.
# Skipping already processed paper: Zoom on the Keystrokes Exploiting Video Calls for Keystroke Inference Attacks
# Skipping already processed paper: zThe Cyber Center For Security and Analytics, The University of Texas at San Antonio, TX, USA
# Skipping already processed paper: zxcvbn Low Budget Password Strength Estimation
# Skipping already processed paper: â  oÏ oÏ  Forward Secure Searchable Encryption.
# Skipping already processed paper: ÆPIC Leak Architecturally Leaking Uninitialized Data from the Microarchitecture
# Skipping already processed paper: Î›Î¿Î»  Functional Lattice Cryptography.
# Skipping already processed paper: μFUZZ Redesign of Parallel Fuzzing using Microservice Architecture
# Skipping already processed paper: μRAI Securing Embedded Systems with Return Address Integrity
# Skipping already processed paper: Доверяи но проверяи SFI safety for native compiled Wasm

# %%
import pandas as pd
import json

# File paths
acm_file = "acm_results_incremental.csv"
results_file = "results_final_2.0_update.csv"
output_file = "results_final_2.0_update_with_domains.csv"

# Load CSVs
acm_df = pd.read_csv(acm_file, encoding="utf-8", on_bad_lines='skip')
results_df = pd.read_csv(results_file, encoding="ISO-8859-1")

# Extract plain title string from JSON
def extract_title(raw):
    try:
        raw = str(raw).strip()
        if raw.startswith("```json"):
            raw = raw[7:].strip()
        if raw.startswith("```"):
            raw = raw[3:].strip()
        if raw.endswith("```"):
            raw = raw[:-3].strip()
        data = json.loads(raw)
        return data.get("title", "").strip()
    except Exception:
        return None

# Clean titles in both files
acm_df['parsed_title'] = acm_df['title'].apply(extract_title)
results_df['parsed_title'] = results_df['title'].apply(extract_title)

# Map title to raw domain string (not parsed, keep full JSON blob)
acm_df['raw_domain'] = acm_df['domain'].astype(str).str.strip()
title_to_raw_domain = dict(zip(acm_df['parsed_title'], acm_df['raw_domain']))

# Copy domain values by matching titles
matched_domains = []
for title in results_df['parsed_title']:
    domain = title_to_raw_domain.get(title, "")
    matched_domains.append(domain)

# Replace the 6th column (index 5 = domain)
results_df.iloc[:, 5] = matched_domains

# Drop helper column
results_df.drop(columns=['parsed_title'], inplace=True)

# Save output
results_df.to_csv(output_file, index=False, encoding='utf-8')
print(f"Domain data successfully merged into: {output_file}")
# Out:
# -----------------------------------------------------
# FileNotFoundError   Traceback (most recent call last)
# Cell In[9], line 10
#       7 output_file = "results_final_2.0_update_with_domains.csv"
#       9 # Load CSVs
# ---> 10 acm_df = pd.read_csv(acm_file, encoding="utf-8", on_bad_lines='skip')
#      11 results_df = pd.read_csv(results_file, encoding="ISO-8859-1")
#      13 # Extract plain title string from JSON
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'acm_results_incremental.csv'
